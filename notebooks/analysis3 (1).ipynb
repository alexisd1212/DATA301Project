# %%
import pandas as pd
# a= eval(r.content) Never user eval for online texts
df = pd.read_csv('./Downloads/application_record.csv.zip')
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
 #df.to_csv("application_record.csv")

# %%
#Benjamin Li
#I want to work with this dataset to better understand the demographics of credit card users and it's role in understanding the finance industry, with particular focus to relevant factors such as educational level,gender, income and employment type and it's relation to credit card applications.

# %%
# Milestone 3

#Task1
import pandas as pd
import numpy as numpy
df = pd.read_csv('./Downloads/application_record.csv.zip')
df

df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
df.shape
# Out:
# (438557, 18)

# %%
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#                    ID   CNT_CHILDREN AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count   438557.000000  438557.000000    438557.000000  438557.000000
# mean   6022176.269842       0.427390    187524.286010  -15997.904649
# std     571637.023257       0.724882    110086.853066    4185.030007
# min    5008804.000000       0.000000     26100.000000  -25201.000000
# 25%    5609375.000000       0.000000    121500.000000  -19483.000000
# 50%    6047745.000000       0.000000    160780.500000  -15630.000000
# 75%    6456971.000000       1.000000    225000.000000  -12514.000000
# max    7999952.000000      19.000000   6750000.000000   -7489.000000
#
#        DAYS_EMPLOYED     FLAG_MOBIL FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000  438557.000000   438557.000000  438557.000000
# mean    60563.675328       1.000000        0.206133       0.287771
# std    138767.799647       0.000000        0.404527       0.452724
# min    -17531.000000       1.000000        0.000000       0.000000
# ...

# %%
print("Number of unique values for each variable:")
print(f"{df.nunique(axis=0)}")
# Out:
# Number of unique values for each variable:
# ID                     438510
# CODE_GENDER                 2
# FLAG_OWN_CAR                2
# FLAG_OWN_REALTY             2
# CNT_CHILDREN               12
# AMT_INCOME_TOTAL          866
# NAME_INCOME_TYPE            5
# NAME_EDUCATION_TYPE         5
# NAME_FAMILY_STATUS          5
# NAME_HOUSING_TYPE           6
# DAYS_BIRTH              16379
# DAYS_EMPLOYED            9406
# FLAG_MOBIL                  1
# FLAG_WORK_PHONE             2
# FLAG_PHONE                  2
# FLAG_EMAIL                  2
# OCCUPATION_TYPE            18
# CNT_FAM_MEMBERS            13
# dtype: int64

# %%
df.describe(include='object').T
# Out:
#                       count unique                            top    freq
# CODE_GENDER          438557      2                              F  294440
# FLAG_OWN_CAR         438557      2                              N  275459
# FLAG_OWN_REALTY      438557      2                              Y  304074
# NAME_INCOME_TYPE     438557      5                        Working  226104
# NAME_EDUCATION_TYPE  438557      5  Secondary / secondary special  301821
# NAME_FAMILY_STATUS   438557      5                        Married  299828
# NAME_HOUSING_TYPE    438557      6              House / apartment  393831
# OCCUPATION_TYPE      304354     18                       Laborers   78240

# %%
# unique values for each column
for col in df.columns:
    print('{} : {}'.format(col,df[col].unique()))
# Out:
# ID : [5008804 5008805 5008806 ... 6841878 6842765 6842885]
# CODE_GENDER : ['M' 'F']
# FLAG_OWN_CAR : ['Y' 'N']
# FLAG_OWN_REALTY : ['Y' 'N']
# CNT_CHILDREN : [ 0  1  3  2  4  5 14 19  7  9 12  6]
# AMT_INCOME_TOTAL : [ 427500.    112500.    270000.    283500.    135000.    130500.
#   157500.    405000.    211500.    360000.    126000.    315000.
#   247500.    297000.    225000.    166500.    216000.    255150.
#   148500.    202500.     94500.    450000.    180000.     90000.
#   765000.    382500.    144000.    229500.    292500.     74250.
#    40500.    337500.    193500.    267750.    139500.     67500.
#   252000.    900000.    115290.    279000.     76500.    234000.
#    81000.    108000.     99000.    198000.     45000.    238500.
#   117000.    153000.   1350000.    445500.    495000.     85500.
#   306000.    562500.    189000.    328500.    310500.    540000.
#   171000.    675000.    121500.     72000.     65250.    184500.
# ...

# %%
# see how many na values exactly
df.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
# examine column types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
#TASK 2

# %%
df_fix = df.copy().drop(['FLAG_OWN_REALTY', 'DAYS_BIRTH',
       'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
       'FLAG_EMAIL'], axis=1)
df_fix
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0       5008804           M            Y             0          427500.0
# 1       5008805           M            Y             0          427500.0
# 2       5008806           M            Y             0          112500.0
# 3       5008808           F            N             0          270000.0
# 4       5008809           F            N             0          270000.0
# ...         ...         ...          ...           ...               ...
# 438552  6840104           M            N             0          135000.0
# 438553  6840222           F            N             0          103500.0
# 438554  6841878           F            N             0           54000.0
# 438555  6842765           F            N             0           72000.0
# 438556  6842885           F            N             0          121500.0
#
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
# Check for duplicated entries:

if len(df_fix[df_fix.duplicated()]) > 0:
    print("No. of duplicated entries: ", len(df_fix[df_fix.duplicated()]))
    print(df_fix[df_fix.duplicated(keep=False)].sort_values(by=list(df_fix.columns)).head())
else:
    print("No duplicated entries found")
# Out:
# No duplicated entries found

# %%
#TASK 3

# %%
def load_and_process(url_or_path_to_csv_file):

    # Method Chain 1 (Load data and deal with missing data)

    df1 = (
          pd.read_csv('./Downloads/application_record.csv.zip')
          .rename(columns={'CODE_GENDER': 'Gender', 'FLAG_OWN_CAR': 'own_car', 'CNT_CHILDREN': 'children', 'AMT_INCOME_TOTAL': 'income',
                          'NAME_INCOME_TYPE': 'Type of Employment', 'NAME_EDUCATION_TYPE': 'Level of Education', 'NAME_FAMILY_STATUS': 'relationship_status',
                          'NAME_HOUSING_TYPE': 'Housing'})
          .fillna("Inconlusive")
          .replace("F", "Female")
          .replace("M", "Male")
          .replace("Y", "Yes")
          .replace("N", "No")
        
    )

    # Method Chain 2 (Create new columns, drop others, and do processing)
    
    df2 = (
          df1.drop(['FLAG_OWN_REALTY', 'DAYS_BIRTH',
       'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
       'FLAG_EMAIL'], axis=1)
    )

    return df2

# %%
df3 = load_and_process('./Downloads/application_record.csv.zip')

# %%
df3.to_csv("Benjamin's_data.csv")
df3
# Out:
#              ID  Gender own_car  children    income    Type of Employment  \
# 0       5008804    Male     Yes         0  427500.0               Working
# 1       5008805    Male     Yes         0  427500.0               Working
# 2       5008806    Male     Yes         0  112500.0               Working
# 3       5008808  Female      No         0  270000.0  Commercial associate
# 4       5008809  Female      No         0  270000.0  Commercial associate
# ...         ...     ...     ...       ...       ...                   ...
# 438552  6840104    Male      No         0  135000.0             Pensioner
# 438553  6840222  Female      No         0  103500.0               Working
# 438554  6841878  Female      No         0   54000.0  Commercial associate
# 438555  6842765  Female      No         0   72000.0             Pensioner
# 438556  6842885  Female      No         0  121500.0               Working
#
#                    Level of Education   relationship_status  \
# ...

# %%
#TASK 4

# %%
df3.describe(include='object').T
# Out:
#                       count unique                            top    freq
# Gender               438557      2                         Female  294440
# own_car              438557      2                             No  275459
# Type of Employment   438557      5                        Working  226104
# Level of Education   438557      5  Secondary / secondary special  301821
# relationship_status  438557      5                        Married  299828
# Housing              438557      6              House / apartment  393831
# OCCUPATION_TYPE      438557     19                    Inconlusive  134203

# %%
#Analysis
#More females than males are credit card users/applicants 
#Most credit card applicants do not own a car 
#Being a working class individual has higher chance to be a credit card user
#The educational level of most credit card users/applicants is not of those with higher education level
# More credit card applicants are married than not married 
# 393831 out of 438557 credit card applicants have House/apartment as major housing type

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Draw a nested barplot by education status and sex
g = sns.catplot(
    data=df3, kind="bar",
    x="own_car", y="income", hue="Level of Education",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Income")
g.legend.set_title("")
g.fig.suptitle("Relationship between Education level and income by car ownership")
g.fig.set_size_inches(20,5)
plt.show()

# %%
#Analysis:
#-Car ownership has higher income in all educational levels 
#-If you own a car that means you are more likely to have the income to afford a car
#-Income correlates with higher education as expected

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Draw a nested barplot by education status and sex
g = sns.catplot(
    data=df3, kind="bar",
    x="Level of Education", y="income", hue="Type of Employment",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Income")
g.legend.set_title("")
g.fig.suptitle("Relationship between Education level and income by employment type")
g.fig.set_size_inches(20,5)
plt.show()

# %%
#Analysis

#The higher the educational level, the higher the income. Academic degree > Higher Education > Incomplete Higher > Secondary > Lower Secondary
#Commercial associate is the highest in all and pensioner is the lowest except lower secondary

# %%
sns.relplot(
    data=df3, x="Level of Education", y="ID",
    col="Type of Employment",
    kind="scatter"
)

# %%
#Analysis
#-Academic degree holders had the least amount of card ownership in all types of employment groups
#-The other levels of education ahd similar levels of card ownership
#-This is possibly because people who have the highest form of education have the most money and don't need to rely on credit cards as often

# %%
plt.figure(figsize = (10, 10))
p = sns.violinplot(x=df3['ID'], y = df3['Type of Employment'], data = df3)
p.set_xlabel('ID', fontsize = 20)
# Out:
# Text(0.5, 0, 'ID')

# %%
#Analysis
#-Students had the least amount of credit card ownership
#-possibly because many are underage and not mature enough yet
#-State servant, Pensioner, Commercial associaate and working class all exhibited similar levels of card ownership

# %%
#Conclusion
#-Employment type and Educational level predict who is more likely to own a credit card
#-Educational level predicts income, and predicts which groups are less likely to own credit cards
#-Employment level predicts which groups are less likely to own credit cards as well and 
#Both are important in understanding the role of credit card usage in society
#Demographics also predicts the credit card ownership such as gender, car ownership, being working class or not, have a house, and whether you are married or not
